# %%
import pandas as pd
import json
import requests
from urllib.parse import quote
# %matplotlib inline 

# Get crime data 
soql = "https://data.cityofchicago.org/resource/6zsd-86xi.json?$query="
soql += quote("SELECT community_area AS Community, count(*)/5 AS Crime_Rate, primary_type AS Primary_Type ")
soql += quote("WHERE 2007 < year AND year < 2013 ")
soql += quote("GROUP BY Community, Primary_Type LIMIT 10000")

resp = requests.get(soql).json()

crime = pd.DataFrame(resp)

# Get rid of the redundant decimal places 
crime.Crime_Rate = crime.Crime_Rate.astype(float)
crime.round(1) 


#ATTENTION HERE: problem with NaN remains unsolved!!!!
crime.dropna(axis = 0, how = "any") 
crime.tail() 

#STOP here before getting into merge 

# Get socioeconomics data 
#socioeconomics = pd.read_csv("Census_Data_-_Selected_socioeconomic_indicators_in_Chicago__2008___2012.csv", index_col = ['Community Area Number'])


# Merge crime data on socioeconomics data using Communty Area Number 
#crime.rename(columns={'Community':'Community Area Number'}, inplace = True)
#crime.set_index('Community Area Number')

#mix = pd.DataFrame.join(crime, socioeconomics)
#mix
# Out:
#      Community  Crime_Rate            Primary_Type
# 2040       NaN         1.2  PUBLIC PEACE VIOLATION
# 2041       NaN         3.2                 ROBBERY
# 2042       NaN         0.4             SEX OFFENSE
# 2043       NaN        44.8                   THEFT
# 2044       NaN         1.0       WEAPONS VIOLATION

# %%
crime.head(100)
# Out:
#    Community  Crime_Rate                      Primary_Type
# 0          0         0.2                           ASSAULT
# 1          0         1.2                           BATTERY
# 2          0         0.2                   CRIMINAL DAMAGE
# 3          0         0.4                 CRIMINAL TRESPASS
# 4          0         1.0                DECEPTIVE PRACTICE
# 5          0         0.2               MOTOR VEHICLE THEFT
# 6          0         0.4                         NARCOTICS
# 7          0         0.8                     OTHER OFFENSE
# 8          0         1.6                             THEFT
# 9          1         4.6                             ARSON
# 10         1       344.8                           ASSAULT
# 11         1      1038.6                           BATTERY
# 12         1       279.6                          BURGLARY
# 13         1       630.6                   CRIMINAL DAMAGE
# 14         1       221.0                 CRIMINAL TRESPASS
# 15         1        22.6               CRIM SEXUAL ASSAULT
# 16         1       206.0                DECEPTIVE PRACTICE
# 17         1        11.0                          GAMBLING
# 18         1         4.0                          HOMICIDE
# 19         1        19.0  INTERFERENCE WITH PUBLIC OFFICER
# 20         1         2.6                      INTIMIDATION
# 21         1         3.8                        KIDNAPPING
# 22         1        15.6              LIQUOR LAW VIOLATION
# 23         1       162.6               MOTOR VEHICLE THEFT
# 24         1       627.8                         NARCOTICS
# 25         1         1.2                         OBSCENITY
# 26         1        32.0        OFFENSE INVOLVING CHILDREN
# 27         1       408.6                     OTHER OFFENSE
# 28         1        35.4                      PROSTITUTION
# 29         1         0.2                  PUBLIC INDECENCY
# ..       ...         ...                               ...
# 70        11         0.6                          HOMICIDE
# 71        11         2.2  INTERFERENCE WITH PUBLIC OFFICER
# 72        11         1.4                      INTIMIDATION
# 73        11         1.4                        KIDNAPPING
# 74        11         5.4              LIQUOR LAW VIOLATION
# 75        11        67.0               MOTOR VEHICLE THEFT
# 76        11        61.8                         NARCOTICS
# 77        11         0.4                         OBSCENITY
# 78        11        19.2        OFFENSE INVOLVING CHILDREN
# 79        11       138.4                     OTHER OFFENSE
# 80        11         0.2                      PROSTITUTION
# 81        11         8.4            PUBLIC PEACE VIOLATION
# 82        11        22.6                           ROBBERY
# 83        11         6.0                       SEX OFFENSE
# 84        11         1.6                          STALKING
# 85        11       337.6                             THEFT
# 86        11         3.2                 WEAPONS VIOLATION
# 87        12         0.8                             ARSON
# 88        12        26.6                           ASSAULT
# 89        12        70.2                           BATTERY
# 90        12        91.0                          BURGLARY
# 91        12       125.6                   CRIMINAL DAMAGE
# 92        12        12.8                 CRIMINAL TRESPASS
# 93        12         2.0               CRIM SEXUAL ASSAULT
# 94        12        39.6                DECEPTIVE PRACTICE
# 95        12         0.2                          GAMBLING
# 96        12         0.4                          HOMICIDE
# 97        12         0.6  INTERFERENCE WITH PUBLIC OFFICER
# 98        12         1.8                        KIDNAPPING
# 99        12         1.4              LIQUOR LAW VIOLATION
#
# [100 rows x 3 columns]
