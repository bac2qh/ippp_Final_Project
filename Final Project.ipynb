# %%
import pandas as pd
import json

# %%
# crime = pd.read_csv("Crimes_-_2001_to_present.csv")
# crime.head()
# Out:
#         ID Case Number                    Date                Block  IUCR  \
# 0  1744168     G553545  09/15/2001 02:00:00 AM      013XX W POLK ST  0460
# 1  1833988     G666677  11/02/2001 06:30:00 PM  002XX W CONGRESS PW  0810
# 2  1896258     G749215  12/15/2001 02:00:00 AM     011XX N STATE ST  0460
# 3  2370646    HH676216  09/26/2002 01:30:00 PM      034XX W 79TH ST  0460
# 4  2378227    HH686534  10/01/2002 07:00:00 PM    022XX W NORTH AVE  0910
#
#           Primary Type Description Location Description  Arrest  Domestic  \
# 0              BATTERY      SIMPLE               STREET   False     False
# 1                THEFT   OVER $500                OTHER   False     False
# 2              BATTERY      SIMPLE               STREET   False     False
# 3              BATTERY      SIMPLE               STREET   False     False
# 4  MOTOR VEHICLE THEFT  AUTOMOBILE               STREET   False     False
#
#      ...     Ward  Community Area  FBI Code  X Coordinate Y Coordinate  Year  \
# 0    ...      NaN             NaN       08B           NaN          NaN  2001
# 1    ...      NaN             NaN        06           NaN          NaN  2001
# 2    ...      NaN             NaN       08B           NaN          NaN  2001
# 3    ...     18.0            70.0       08B           NaN          NaN  2002
# 4    ...      1.0            24.0        07           NaN          NaN  2002
#
#                Updated On  Latitude Longitude  Location
# 0  08/17/2015 03:03:40 PM       NaN       NaN       NaN
# 1  08/17/2015 03:03:40 PM       NaN       NaN       NaN
# 2  08/17/2015 03:03:40 PM       NaN       NaN       NaN
# 3  08/17/2015 03:03:40 PM       NaN       NaN       NaN
# 4  08/17/2015 03:03:40 PM       NaN       NaN       NaN
#
# [5 rows x 22 columns]

# %%
crime_usecols = pd.read_csv("Crimes_-_2001_to_present.csv", usecols =[
    'Date', 'Block', 'IUCR', 'Primary Type', 'Description',
    'Location Description', 'Arrest', 'Domestic', 'Beat', 'District', 
    'Ward', 'Community Area', 'FBI Code', 'Year', 'Updated On'
])

# %%
crime_0812 = crime_usecols[crime_usecols['Year'].isin([2008, 2009, 2010, 2011, 2012])]

# %%
# len(crime_0812)
# Out:
# 1877285

# %%
# crime_0812.keys()
# Out:
# Index(['Date', 'Block', 'IUCR', 'Primary Type', 'Description',
#        'Location Description', 'Arrest', 'Domestic', 'Beat', 'District',
#        'Ward', 'Community Area', 'FBI Code', 'Year', 'Updated On'],
#       dtype='object')

# %%
crime_0812_1 = crime_0812.copy()
crime_0812_1['Community Area'] = crime_0812['Community Area'].dropna(axis = 0, how='any')

# %%
# crime_0812_1.head()
# len(crime_0812_1)
# Out:
# 1877285

# %%
crimes = crime_0812_1.copy()

# %%
socioeconomic = pd.read_csv("Census_Data_-_Selected_socioeconomic_indicators_in_Chicago__2008___2012.csv")
socioeconomic.head()
# Out:
#    Community Area Number COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0                    1.0         Rogers Park                         7.7
# 1                    2.0          West Ridge                         7.8
# 2                    3.0              Uptown                         3.8
# 3                    4.0      Lincoln Square                         3.4
# 4                    5.0        North Center                         0.3
#
#    PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 0                              23.6                          8.7
# 1                              17.2                          8.8
# 2                              24.0                          8.9
# 3                              10.9                          8.2
# 4                               7.5                          5.2
#
#    PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 0                                          18.2
# 1                                          20.8
# 2                                          11.8
# 3                                          13.4
# 4                                           4.5
#
#    PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME   HARDSHIP INDEX
# 0                              27.5               23939            39.0
# 1                              38.5               23040            46.0
# 2                              22.2               35787            20.0
# 3                              25.5               37524            17.0
# 4                              26.2               57123             6.0

# %%
crimes.rename(columns={'Community Area':'Community Area Number'}, inplace = True)

# %%
# crimes.keys()
# Out:
# Index(['Date', 'Block', 'IUCR', 'Primary Type', 'Description',
#        'Location Description', 'Arrest', 'Domestic', 'Beat', 'District',
#        'Ward', 'Community Area Number', 'FBI Code', 'Year', 'Updated On'],
#       dtype='object')

# %%
mix = pd.merge(crimes, socioeconomic, on = 'Community Area Number')

# %%
mix.head()
# Out:
#                      Date                    Block  IUCR         Primary Type  \
# 0  02/26/2008 12:00:00 AM       075XX N OAKLEY AVE  0910  MOTOR VEHICLE THEFT
# 1  10/10/2009 09:50:00 PM  024XX W NORTH SHORE AVE  0810                THEFT
# 2  06/25/2012 12:00:00 PM      056XX N ROCKWELL ST  1153   DECEPTIVE PRACTICE
# 3  05/08/2008 08:30:00 PM       027XX W ARTHUR AVE  0930  MOTOR VEHICLE THEFT
# 4  09/16/2008 12:00:00 PM       064XX N SEELEY AVE  0820                THEFT
#
#                            Description Location Description  Arrest  Domestic  \
# 0                           AUTOMOBILE               STREET   False     False
# 1                            OVER $500               STREET   False     False
# 2  FINANCIAL IDENTITY THEFT OVER $ 300            RESIDENCE   False     False
# 3           THEFT/RECOVERY: AUTOMOBILE               STREET   False     False
# 4                       $500 AND UNDER               STREET   False     False
#
#    Beat  District       ...        Year              Updated On  \
# 0  2411      24.0       ...        2008  08/17/2015 03:03:40 PM
# 1  2412      24.0       ...        2009  08/17/2015 03:03:40 PM
# 2  2011      20.0       ...        2012  08/17/2015 03:03:40 PM
# 3  2412      24.0       ...        2008  08/17/2015 03:03:40 PM
# 4  2412      24.0       ...        2008  08/17/2015 03:03:40 PM
#
#   COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0          West Ridge                         7.8
# 1          West Ridge                         7.8
# 2          West Ridge                         7.8
# 3          West Ridge                         7.8
# 4          West Ridge                         7.8
#
#   PERCENT HOUSEHOLDS BELOW POVERTY PERCENT AGED 16+ UNEMPLOYED  \
# 0                             17.2                         8.8
# 1                             17.2                         8.8
# 2                             17.2                         8.8
# 3                             17.2                         8.8
# 4                             17.2                         8.8
#
#    PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 0                                          20.8
# 1                                          20.8
# 2                                          20.8
# 3                                          20.8
# 4                                          20.8
#
#    PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME   HARDSHIP INDEX
# 0                              38.5               23040            46.0
# 1                              38.5               23040            46.0
# 2                              38.5               23040            46.0
# 3                              38.5               23040            46.0
# 4                              38.5               23040            46.0
#
# [5 rows x 23 columns]
